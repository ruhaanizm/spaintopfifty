# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("data/raw/Atlantic_Spain.csv")
df.head()
# Out:
#          date  position         song                      artist  popularity  \
# 0  18-05-2024         1    Supernova                       Saiko          84
# 1  18-05-2024         2     EL TONTO                 Lola Indigo          83
# 2  18-05-2024         3    Acróstico                     Shakira          81
# 3  18-05-2024         4         BESO    ROSALÍA & Rauw Alejandro          96
# 4  18-05-2024         5  El Merengue  Marshmello & Manuel Turizo          91
#
#    duration_ms album_type  total_tracks  is_explicit  \
# 0       190909     single             1        False
# 1       187986      album            11        False
# 2       170785     single             1        False
# 3       194543     single             3        False
# 4       189668     single             1        False
#
#                                      album_cover_url
# 0  https://i.scdn.co/image/ab67616d0000b273c3f5b9...
# 1  https://i.scdn.co/image/ab67616d0000b273daab36...
# 2  https://i.scdn.co/image/ab67616d0000b273bd6bbd...
# 3  https://i.scdn.co/image/ab67616d0000b2734d6cf0...
# 4  https://i.scdn.co/image/ab67616d0000b273f40467...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27800 entries, 0 to 27799
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             27800 non-null  object
#  1   position         27800 non-null  int64
#  2   song             27800 non-null  object
#  3   artist           27800 non-null  object
#  4   popularity       27800 non-null  int64
#  5   duration_ms      27800 non-null  int64
#  6   album_type       27800 non-null  object
#  7   total_tracks     27800 non-null  int64
#  8   is_explicit      27800 non-null  bool
#  9   album_cover_url  27800 non-null  object
# dtypes: bool(1), int64(4), object(5)
# memory usage: 1.9+ MB

# %%
df['date_new'] = pd.to_datetime(df['date'], dayfirst=True)

counts = df.groupby('date_new').size()
counts.value_counts()
# Out:
# 50     554
# 100      1
# Name: count, dtype: int64

# %%
counts[counts != 50]
# Out:
# date_new
# 2025-03-01    100
# dtype: int64

# %%
df[df['date_new'] == '2025-03-01'].sort_values('position')
# Out:
#              date  position                song                   artist  \
# 14350  01-03-2025         1              FARDOS  JC Reyes & De La Ghetto
# 14400  01-03-2025         1              FARDOS  JC Reyes & De La Ghetto
# 14401  01-03-2025         2         Manos Rotas      DELLAFUENTE & Morad
# 14351  01-03-2025         2         Manos Rotas      DELLAFUENTE & Morad
# 14352  01-03-2025         3            LA FALDA              Myke Towers
# ...           ...       ...                 ...                      ...
# 14447  01-03-2025        48         Tacos Gucci                 Anuel AA
# 14448  01-03-2025        49    NO PIENSO LLAMAR             Soge Culebra
# 14398  01-03-2025        49         Tacos Gucci                 Anuel AA
# 14399  01-03-2025        50  TU$$I (with Dei V)               YOVNGCHIMI
# 14449  01-03-2025        50  TU$$I (with Dei V)               YOVNGCHIMI
#
#        popularity  duration_ms album_type  total_tracks  is_explicit  \
# 14350          78       183335     single             1        False
# 14400          79       183335     single             1        False
# 14401          85       168594     single             1        False
# 14351          85       168594     single             1        False
# 14352          94       174229      album            23         True
# ...           ...          ...        ...           ...          ...
# 14447          84       207157     single             1         True
# 14448          70       198352      album            13        False
# 14398          84       207157     single             1         True
# 14399          76       163200      album            16         True
# 14449          76       163200      album            16         True
#
#                                          album_cover_url   date_new
# 14350  https://i.scdn.co/image/ab67616d0000b27344d0e1... 2025-03-01
# 14400  https://i.scdn.co/image/ab67616d0000b27344d0e1... 2025-03-01
# 14401  https://i.scdn.co/image/ab67616d0000b2731a176d... 2025-03-01
# 14351  https://i.scdn.co/image/ab67616d0000b2731a176d... 2025-03-01
# 14352  https://i.scdn.co/image/ab67616d0000b273c75c05... 2025-03-01
# ...                                                  ...        ...
# 14447  https://i.scdn.co/image/ab67616d0000b2734b021a... 2025-03-01
# 14448  https://i.scdn.co/image/ab67616d0000b273890db8... 2025-03-01
# 14398  https://i.scdn.co/image/ab67616d0000b2734b021a... 2025-03-01
# 14399  https://i.scdn.co/image/ab67616d0000b2737f78a2... 2025-03-01
# 14449  https://i.scdn.co/image/ab67616d0000b2737f78a2... 2025-03-01
#
# [100 rows x 11 columns]

# %%
# repeating values, dropping duplicates
df.drop_duplicates(subset=['date_new', 'position'], inplace=True)

# %%
df[df['date_new'] == '2025-03-01'].sort_values('position')
# Out:
#              date  position  \
# 14350  01-03-2025         1
# 14351  01-03-2025         2
# 14352  01-03-2025         3
# 14353  01-03-2025         4
# 14354  01-03-2025         5
# 14355  01-03-2025         6
# 14356  01-03-2025         7
# 14357  01-03-2025         8
# 14358  01-03-2025         9
# 14359  01-03-2025        10
# 14360  01-03-2025        11
# 14361  01-03-2025        12
# 14362  01-03-2025        13
# 14363  01-03-2025        14
# 14364  01-03-2025        15
# 14365  01-03-2025        16
# 14366  01-03-2025        17
# 14367  01-03-2025        18
# 14368  01-03-2025        19
# 14369  01-03-2025        20
# 14370  01-03-2025        21
# 14371  01-03-2025        22
# 14372  01-03-2025        23
# 14373  01-03-2025        24
# 14374  01-03-2025        25
# 14375  01-03-2025        26
# 14376  01-03-2025        27
# 14377  01-03-2025        28
# 14378  01-03-2025        29
# 14379  01-03-2025        30
# 14380  01-03-2025        31
# 14381  01-03-2025        32
# 14382  01-03-2025        33
# 14383  01-03-2025        34
# 14384  01-03-2025        35
# 14385  01-03-2025        36
# 14386  01-03-2025        37
# 14387  01-03-2025        38
# 14388  01-03-2025        39
# 14389  01-03-2025        40
# 14390  01-03-2025        41
# 14391  01-03-2025        42
# 14392  01-03-2025        43
# 14393  01-03-2025        44
# 14394  01-03-2025        45
# 14395  01-03-2025        46
# 14396  01-03-2025        47
# 14397  01-03-2025        48
# 14398  01-03-2025        49
# 14399  01-03-2025        50
#
#                                                     song  \
# 14350                                             FARDOS
# 14351                                        Manos Rotas
# 14352                                           LA FALDA
# 14353                                          X'CLUSIVO
# 14354                                               LUNA
# 14355                                              M.A.I
# 14356                      Una Foto Remix (feat. Emilia)
# 14357           Young Miko: Bzrp Music Sessions, Vol. 58
# 14358                       Mamichula - con Nicki Nicole
# 14359                                           Casanova
# 14360                                          Gata Only
# 14361                              No Te Quieren Conmigo
# 14362                                    La_Original.mp3
# 14363                                          LA ÚLTIMA
# 14364                                        PERRO NEGRO
# 14365                                           El Patio
# 14366                                        UNA BACHATA
# 14367                                     Buscando Money
# 14368                                              A 300
# 14369                              CONTIGO (with Tiësto)
# 14370                                           Columbia
# 14371                                            BAD BOY
# 14372                                           MODELITO
# 14373                                            LA CAPI
# 14374                                              REINA
# 14375                                            DILUVIO
# 14376                               COSAS QUE NO TE DIJE
# 14377                                              QLONA
# 14378                                         EMPELOTICA
# 14379                                       Hey Lil Mama
# 14380                      Narcotics (with Bryant Myers)
# 14381                                        Madrid City
# 14382                                         BABY HELLO
# 14383                                                 OA
# 14384                                    POLARIS - Remix
# 14385  Japoni (feat. Camin, Moncho Chavea, Jthyago & ...
# 14386                                         La Bachata
# 14387                                               LALA
# 14388                                        Si No Estás
# 14389                                             Buenas
# 14390                                    Quien Es Dei V?
# 14391                                     ASI ES LA VIDA
# 14392                                      lady madrizZz
# 14393                                          VAGABUNDO
# 14394                                            Holanda
# 14395                                           El Cielo
# 14396                                   NO PIENSO LLAMAR
# 14397                                           El Mambo
# 14398                                        Tacos Gucci
# 14399                                 TU$$I (with Dei V)
#
#                                         artist  popularity  duration_ms  \
# 14350                  JC Reyes & De La Ghetto          78       183335
# 14351                      DELLAFUENTE & Morad          85       168594
# 14352                              Myke Towers          94       174229
# 14353                                    Gonzy          81       175586
# 14354                                     Feid          97       196800
# 14355                                   Milo j          89       184027
# 14356        Mesita & Nicki Nicole & Tiago PZK          92       243898
# 14357                    Bizarrap & Young Miko          94       187172
# 14358                                   Trueno          88       219201
# 14359            Soolking & Lola Indigo & Rvfv          83       243806
# 14360                     FloyyMenor & Cris Mj          90       222000
# 14361           Gaby Music & Lunay & Luar La L          89       252040
# 14362                                   Emilia          85       140625
# 14363                                  Quevedo          84       170322
# 14364                                Bad Bunny          95       162767
# 14365          Pepe y Vizio & Delaossa & KIDDO          73       232645
# 14366                              Lola Indigo          77       157846
# 14367                TWENTY SIX & Tayson Kryss          60       150000
# 14368    JC Reyes & Pedro Calderon & Blacknife          79       169208
# 14369                         KAROL G & Tiësto          90       192786
# 14370                                  Quevedo          92       186000
# 14371          Chris Jedi & Gaby Music & Dei V          77       235146
# 14372                                     Mora          83       190496
# 14373                              Myke Towers          80       202360
# 14374                                     Mora          84       211879
# 14375                           Rauw Alejandro          90       197052
# 14376                                    Saiko          84       224725
# 14377                                  KAROL G          93       172797
# 14378                     Lenny Tavárez & Feid          77       190322
# 14379                           Eladio Carrion          86       216338
# 14380                     Dei V & Bryant Myers          84       173991
# 14381                                 Ana Mena          79       172727
# 14382                           Rauw Alejandro          78       222461
# 14383              Anuel AA & Quevedo & Maluma          86       235200
# 14384                   Saiko & Feid & Quevedo          83       288000
# 14385   Oscar el Ruso & Samuel G & Omar Montes          77       248004
# 14386                            Manuel Turizo          87       162637
# 14387                              Myke Towers          92       197920
# 14388                           iñigo quintero          93       184061
# 14389                          Quevedo & Saiko          80       192954
# 14390                                    Dei V          81       162244
# 14391         Enrique Iglesias & Maria Becerra          84       172095
# 14392                                     céro          75       131020
# 14393  Sebastian Yatra & Manuel Turizo & Beéle          86       215600
# 14394                                   Jhayco          86       231693
# 14395       Sky Rompiendo & Feid & Myke Towers          85       191320
# 14396                             Soge Culebra          70       198352
# 14397                              Kiko Rivera          76       129845
# 14398                                 Anuel AA          84       207157
# 14399                               YOVNGCHIMI          76       163200
#
#       album_type  total_tracks  is_explicit  \
# 14350     single             1        False
# 14351     single             1        False
# 14352      album            23         True
# 14353     single             1         True
# 14354      album            10        False
# 14355      album            10        False
# 14356     single             1        False
# 14357     single             1        False
# 14358      album            10        False
# 14359     single             1        False
# 14360     single             1         True
# 14361     single             1        False
# 14362      album            13        False
# 14363     single             1        False
# 14364      album            22         True
# 14365     single             1        False
# 14366      album             7        False
# 14367     single             2        False
# 14368     single             1        False
# 14369     single             1        False
# 14370     single             1        False
# 14371     single             1         True
# 14372      album            14         True
# 14373      album            23         True
# 14374      album            15         True
# 14375      album            14         True
# 14376     single             1        False
# 14377      album             9         True
# 14378     single             1         True
# 14379      album            17        False
# 14380     single             1         True
# 14381     single             1        False
# 14382      album            14         True
# 14383     single             1         True
# 14384     single             1         True
# 14385     single             1        False
# 14386      album            15        False
# 14387      album            23         True
# 14388     single             1        False
# 14389     single             1        False
# 14390     single             1         True
# 14391     single             1        False
# 14392     single             1        False
# 14393     single             1        False
# 14394     single             1         True
# 14395     single             1         True
# 14396      album            13        False
# 14397     single             1        False
# 14398     single             1         True
# 14399      album            16         True
#
#                                          album_cover_url   date_new
# 14350  https://i.scdn.co/image/ab67616d0000b27344d0e1... 2025-03-01
# 14351  https://i.scdn.co/image/ab67616d0000b2731a176d... 2025-03-01
# 14352  https://i.scdn.co/image/ab67616d0000b273c75c05... 2025-03-01
# 14353  https://i.scdn.co/image/ab67616d0000b2730d794d... 2025-03-01
# 14354  https://i.scdn.co/image/ab67616d0000b273f1aad8... 2025-03-01
# 14355  https://i.scdn.co/image/ab67616d0000b27398ee8f... 2025-03-01
# 14356  https://i.scdn.co/image/ab67616d0000b273d7e325... 2025-03-01
# 14357  https://i.scdn.co/image/ab67616d0000b2737b5840... 2025-03-01
# 14358  https://i.scdn.co/image/ab67616d0000b273f4483d... 2025-03-01
# 14359  https://i.scdn.co/image/ab67616d0000b2732adf05... 2025-03-01
# 14360  https://i.scdn.co/image/ab67616d0000b2731d0777... 2025-03-01
# 14361  https://i.scdn.co/image/ab67616d0000b2732a3429... 2025-03-01
# 14362  https://i.scdn.co/image/ab67616d0000b273bfb945... 2025-03-01
# 14363  https://i.scdn.co/image/ab67616d0000b27366a722... 2025-03-01
# 14364  https://i.scdn.co/image/ab67616d0000b2737b1fc5... 2025-03-01
# 14365  https://i.scdn.co/image/ab67616d0000b273531164... 2025-03-01
# 14366  https://i.scdn.co/image/ab67616d0000b27346dd0b... 2025-03-01
# 14367  https://i.scdn.co/image/ab67616d0000b27304a5e9... 2025-03-01
# 14368  https://i.scdn.co/image/ab67616d0000b273827446... 2025-03-01
# 14369  https://i.scdn.co/image/ab67616d0000b273c5426d... 2025-03-01
# 14370  https://i.scdn.co/image/ab67616d0000b273a00a81... 2025-03-01
# 14371  https://i.scdn.co/image/ab67616d0000b2734e3fa2... 2025-03-01
# 14372  https://i.scdn.co/image/ab67616d0000b273076ef0... 2025-03-01
# 14373  https://i.scdn.co/image/ab67616d0000b273c75c05... 2025-03-01
# 14374  https://i.scdn.co/image/ab67616d0000b2734cc96e... 2025-03-01
# 14375  https://i.scdn.co/image/ab67616d0000b273f79b1a... 2025-03-01
# 14376  https://i.scdn.co/image/ab67616d0000b273fb045f... 2025-03-01
# 14377  https://i.scdn.co/image/ab67616d0000b273d026bf... 2025-03-01
# 14378  https://i.scdn.co/image/ab67616d0000b2732733f7... 2025-03-01
# 14379  https://i.scdn.co/image/ab67616d0000b273ec105e... 2025-03-01
# 14380  https://i.scdn.co/image/ab67616d0000b2735b8ec2... 2025-03-01
# 14381  https://i.scdn.co/image/ab67616d0000b2739c3dc8... 2025-03-01
# 14382  https://i.scdn.co/image/ab67616d0000b273f79b1a... 2025-03-01
# 14383  https://i.scdn.co/image/ab67616d0000b27331e30d... 2025-03-01
# 14384  https://i.scdn.co/image/ab67616d0000b2738f4a27... 2025-03-01
# 14385  https://i.scdn.co/image/ab67616d0000b273dd62eb... 2025-03-01
# 14386  https://i.scdn.co/image/ab67616d0000b2734dd995... 2025-03-01
# 14387  https://i.scdn.co/image/ab67616d0000b2730656d5... 2025-03-01
# 14388  https://i.scdn.co/image/ab67616d0000b2735cb953... 2025-03-01
# 14389  https://i.scdn.co/image/ab67616d0000b27347dde0... 2025-03-01
# 14390  https://i.scdn.co/image/ab67616d0000b27348093f... 2025-03-01
# 14391  https://i.scdn.co/image/ab67616d0000b2733d2a29... 2025-03-01
# 14392  https://i.scdn.co/image/ab67616d0000b2736eb7f1... 2025-03-01
# 14393  https://i.scdn.co/image/ab67616d0000b2732d6016... 2025-03-01
# 14394  https://i.scdn.co/image/ab67616d0000b273cd2ceb... 2025-03-01
# 14395  https://i.scdn.co/image/ab67616d0000b27306eccb... 2025-03-01
# 14396  https://i.scdn.co/image/ab67616d0000b273890db8... 2025-03-01
# 14397  https://i.scdn.co/image/ab67616d0000b2739550e7... 2025-03-01
# 14398  https://i.scdn.co/image/ab67616d0000b2734b021a... 2025-03-01
# 14399  https://i.scdn.co/image/ab67616d0000b2737f78a2... 2025-03-01

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)
df.drop(columns=['date_new'], inplace=True)

# %%
df.groupby('date').size().value_counts()
# Out:
# 50    555
# Name: count, dtype: int64

# %% [markdown]
# ## Normalizing Song and artist naming

# %%
df['song'] = df['song'].str.strip().str.lower()
df['artist'] = df['artist'].str.strip().str.lower()

# %%
#creating a unique song id to identify individual songs

df['song_id'] = df['song'] + '_' + df['artist']

# %%
first_appearance = df.groupby('song_id')['date'].min().reset_index()
first_appearance.rename(columns={'date': 'entry_date'}, inplace=True)

# %%
df = df.merge(first_appearance, on='song_id', how='left')

# %%
df[['song', 'artist', 'date', 'entry_date']].head()
# Out:
#           song                      artist       date entry_date
# 0    supernova                       saiko 2024-05-18 2024-05-18
# 1     el tonto                 lola indigo 2024-05-18 2024-05-18
# 2    acróstico                     shakira 2024-05-18 2024-05-18
# 3         beso    rosalía & rauw alejandro 2024-05-18 2024-05-18
# 4  el merengue  marshmello & manuel turizo 2024-05-18 2024-05-18

# %%
df.head()
# Out:
#         date  position         song                      artist  popularity  \
# 0 2024-05-18         1    supernova                       saiko          84
# 1 2024-05-18         2     el tonto                 lola indigo          83
# 2 2024-05-18         3    acróstico                     shakira          81
# 3 2024-05-18         4         beso    rosalía & rauw alejandro          96
# 4 2024-05-18         5  el merengue  marshmello & manuel turizo          91
#
#    duration_ms album_type  total_tracks  is_explicit  \
# 0       190909     single             1        False
# 1       187986      album            11        False
# 2       170785     single             1        False
# 3       194543     single             3        False
# 4       189668     single             1        False
#
#                                      album_cover_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273c3f5b9...
# 1  https://i.scdn.co/image/ab67616d0000b273daab36...
# 2  https://i.scdn.co/image/ab67616d0000b273bd6bbd...
# 3  https://i.scdn.co/image/ab67616d0000b2734d6cf0...
# 4  https://i.scdn.co/image/ab67616d0000b273f40467...
#
#                                   song_id entry_date
# 0                         supernova_saiko 2024-05-18
# 1                    el tonto_lola indigo 2024-05-18
# 2                       acróstico_shakira 2024-05-18
# 3           beso_rosalía & rauw alejandro 2024-05-18
# 4  el merengue_marshmello & manuel turizo 2024-05-18

# %%
song_group = df.groupby('song_id')

# %%
lifecycle_df = song_group.agg(
    entry_date=('date', 'min'),
    exit_date=('date', 'max')
).reset_index()

# %%
lifecycle_df['total_days'] = (
    lifecycle_df['exit_date'] - lifecycle_df['entry_date']
).dt.days + 1

#(+1 because same day = 1 day, not 0)

# %%
peak_pos = song_group['position'].min().reset_index()
peak_pos.rename(columns={'position': 'peak_position'}, inplace=True)

lifecycle_df = lifecycle_df.merge(peak_pos, on='song_id')

# %%
# time to peak

peak_dates = df.loc[df.groupby('song_id')['position'].idxmin()][['song_id', 'date']]
peak_dates.rename(columns={'date': 'peak_date'}, inplace=True)

lifecycle_df = lifecycle_df.merge(peak_dates, on='song_id')

lifecycle_df['time_to_peak'] = (
    lifecycle_df['peak_date'] - lifecycle_df['entry_date']
).dt.days

# %%
lifecycle_df.head()
# Out:
#                                              song_id entry_date  exit_date  \
# 0                                   0 confianza_rvfv 2025-06-02 2025-06-23
# 1                       1 de enero, puntacana_rels b 2025-04-28 2025-04-28
# 2              1000cosas_lola indigo & manuel turizo 2025-03-10 2025-11-13
# 3  100xciento_foreign teck & eladio carrion & de ... 2025-04-30 2025-05-15
# 4                                14 febreros_quevedo 2025-11-24 2025-11-27
#
#    total_days  peak_position  peak_date  time_to_peak
# 0          22             23 2025-06-07             5
# 1           1             45 2025-04-28             0
# 2         249              3 2025-03-10             0
# 3          16             13 2025-05-11            11
# 4           4              9 2025-11-24             0

# %%
df[df['song'].str.startswith(('0', '1'))][['song', 'artist']].head()
# Out:
#             song                       artist
# 14802  1000cosas  lola indigo & manuel turizo
# 14853  1000cosas  lola indigo & manuel turizo
# 14903  1000cosas  lola indigo & manuel turizo
# 14952  1000cosas  lola indigo & manuel turizo
# 15002  1000cosas  lola indigo & manuel turizo

# %%
lifecycle_df['song_id'].iloc[0]
# Out:
# '0 confianza_rvfv'

# %%
df[df['song_id'].str.startswith(('0','14'))]['song_id']
# Out:
# 18939       0 confianza_rvfv
# 19080       0 confianza_rvfv
# 19124       0 confianza_rvfv
# 19172       0 confianza_rvfv
# 19222       0 confianza_rvfv
# 19278       0 confianza_rvfv
# 19327       0 confianza_rvfv
# 19377       0 confianza_rvfv
# 19425       0 confianza_rvfv
# 19475       0 confianza_rvfv
# 19525       0 confianza_rvfv
# 19575       0 confianza_rvfv
# 19627       0 confianza_rvfv
# 19677       0 confianza_rvfv
# 19728       0 confianza_rvfv
# 19778       0 confianza_rvfv
# 19829       0 confianza_rvfv
# 19883       0 confianza_rvfv
# 19941       0 confianza_rvfv
# 19991       0 confianza_rvfv
# 27558    14 febreros_quevedo
# 27612    14 febreros_quevedo
# 27665    14 febreros_quevedo
# 27715    14 febreros_quevedo
# Name: song_id, dtype: object

# %% [markdown]
# those are just song names starting with numbers, like 0 confianza, 69, 14 febreros

# %%
df.to_csv("data/processed/cleaned_data.csv", index=False)
lifecycle_df.to_csv("data/processed/lifecycle_data.csv", index=False)

# %% [markdown]
# Lifecycle Stage Classification
# Classify songs into stages:
#
# • New Entry (≤7 days)
# • Growth Phase (rank improving)
# • Peak Phase (Top 10 stability)
# • Mature Phase (stable mid-rank)
# • Decline Phase (rank deterioration)

# %%
df['days_since_entry'] = (df['date'] - df['entry_date']).dt.days

# %%
df = df.sort_values(['song_id', 'date'])

# %%
df.head()
# Out:
#             date  position         song artist  popularity  duration_ms  \
# 18939 2025-06-02        40  0 confianza   rvfv          35       217500
# 19080 2025-06-05        31  0 confianza   rvfv          57       217500
# 19124 2025-06-06        25  0 confianza   rvfv          57       217500
# 19172 2025-06-07        23  0 confianza   rvfv          57       217500
# 19222 2025-06-08        23  0 confianza   rvfv          57       217500
#
#       album_type  total_tracks  is_explicit  \
# 18939      album            20        False
# 19080      album            20        False
# 19124      album            20        False
# 19172      album            20        False
# 19222      album            20        False
#
#                                          album_cover_url           song_id  \
# 18939  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19080  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19124  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19172  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19222  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
#
#       entry_date  days_since_entry
# 18939 2025-06-02                 0
# 19080 2025-06-02                 3
# 19124 2025-06-02                 4
# 19172 2025-06-02                 5
# 19222 2025-06-02                 6

# %%
df['prev_position'] = df.groupby('song_id')['position'].shift(1)
df['rank_change'] = df['prev_position'] - df['position']

# %%
df.head()
# Out:
#             date  position         song artist  popularity  duration_ms  \
# 18939 2025-06-02        40  0 confianza   rvfv          35       217500
# 19080 2025-06-05        31  0 confianza   rvfv          57       217500
# 19124 2025-06-06        25  0 confianza   rvfv          57       217500
# 19172 2025-06-07        23  0 confianza   rvfv          57       217500
# 19222 2025-06-08        23  0 confianza   rvfv          57       217500
#
#       album_type  total_tracks  is_explicit  \
# 18939      album            20        False
# 19080      album            20        False
# 19124      album            20        False
# 19172      album            20        False
# 19222      album            20        False
#
#                                          album_cover_url           song_id  \
# 18939  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19080  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19124  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19172  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
# 19222  https://i.scdn.co/image/ab67616d0000b273c172e8...  0 confianza_rvfv
#
#       entry_date  days_since_entry  prev_position  rank_change
# 18939 2025-06-02                 0            NaN          NaN
# 19080 2025-06-02                 3           40.0          9.0
# 19124 2025-06-02                 4           31.0          6.0
# 19172 2025-06-02                 5           25.0          2.0
# 19222 2025-06-02                 6           23.0          0.0

# %%
df['stage'] = 'Other'  # default

df.loc[df['days_since_entry'] <= 7, 'stage'] = 'New Entry'

# %%
# if song in top 10

df.loc[df['position'] <= 10, 'stage'] = 'Peak'

# %%
# if song is growing

df.loc[
    (df['rank_change'] > 0) & (df['stage'] == 'Other'),
    'stage'
] = 'Growth'

# %%
# if song is declining
df.loc[
    (df['rank_change'] < 0) & (df['stage'] == 'Other'),
    'stage'
] = 'Decline'

# %%
# song reached maturity

df.loc[df['stage'] == 'Other', 'stage'] = 'Mature'

# %%
df['stage'].value_counts()
# Out:
# stage
# Decline      7746
# Growth       5996
# Mature       5834
# Peak         5550
# New Entry    2624
# Name: count, dtype: int64

# %%
df[df['song_id'] == df['song_id'].iloc[0]][
    ['date', 'position', 'rank_change', 'stage']
]
# Out:
#             date  position  rank_change      stage
# 18939 2025-06-02        40          NaN  New Entry
# 19080 2025-06-05        31          9.0  New Entry
# 19124 2025-06-06        25          6.0  New Entry
# 19172 2025-06-07        23          2.0  New Entry
# 19222 2025-06-08        23          0.0  New Entry
# 19278 2025-06-09        29         -6.0  New Entry
# 19327 2025-06-10        28          1.0     Growth
# 19377 2025-06-11        28          0.0     Mature
# 19425 2025-06-12        26          2.0     Growth
# 19475 2025-06-13        26          0.0     Mature
# 19525 2025-06-14        26          0.0     Mature
# 19575 2025-06-15        26          0.0     Mature
# 19627 2025-06-16        28         -2.0    Decline
# 19677 2025-06-17        28          0.0     Mature
# 19728 2025-06-18        29         -1.0    Decline
# 19778 2025-06-19        29          0.0     Mature
# 19829 2025-06-20        30         -1.0    Decline
# 19883 2025-06-21        34         -4.0    Decline
# 19941 2025-06-22        42         -8.0    Decline
# 19991 2025-06-23        42          0.0     Mature

# %%
lifecycle_df.head()
# Out:
#                                              song_id entry_date  exit_date  \
# 0                                   0 confianza_rvfv 2025-06-02 2025-06-23
# 1                       1 de enero, puntacana_rels b 2025-04-28 2025-04-28
# 2              1000cosas_lola indigo & manuel turizo 2025-03-10 2025-11-13
# 3  100xciento_foreign teck & eladio carrion & de ... 2025-04-30 2025-05-15
# 4                                14 febreros_quevedo 2025-11-24 2025-11-27
#
#    total_days  peak_position  peak_date  time_to_peak
# 0          22             23 2025-06-07             5
# 1           1             45 2025-04-28             0
# 2         249              3 2025-03-10             0
# 3          16             13 2025-05-11            11
# 4           4              9 2025-11-24             0

# %%
df.to_csv("data/processed/data_with_stages.csv", index=False)

# %% [markdown]
# Playlist Rotation & Churn Analysis
# • Daily entry and exit counts
# • Average churn rate
# • Stability vs volatility measurement
# • Rotation comparison across months

# %%
daily_songs = df.groupby('date')['song_id'].apply(set).reset_index()

# %%
daily_songs
# Out:
#           date                                            song_id
# 0   2024-05-18  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 1   2024-05-19  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 2   2024-05-20  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 3   2024-05-21  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 4   2024-05-22  {antes_rvfv & edu garcía, classy 101_feid & yo...
# ..         ...                                                ...
# 550 2025-11-23  {martini_dei v, me has invitado a bailar_dani ...
# 551 2025-11-24  {mr. moondial_quevedo, me has invitado a baila...
# 552 2025-11-25  {mr. moondial_quevedo, me has invitado a baila...
# 553 2025-11-26  {mr. moondial_quevedo, me has invitado a baila...
# 554 2025-11-27  {mr. moondial_quevedo, me has invitado a baila...
#
# [555 rows x 2 columns]

# %%
daily_songs = daily_songs.sort_values('date')
daily_songs
# Out:
#           date                                            song_id
# 0   2024-05-18  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 1   2024-05-19  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 2   2024-05-20  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 3   2024-05-21  {antes_rvfv & edu garcía, classy 101_feid & yo...
# 4   2024-05-22  {antes_rvfv & edu garcía, classy 101_feid & yo...
# ..         ...                                                ...
# 550 2025-11-23  {martini_dei v, me has invitado a bailar_dani ...
# 551 2025-11-24  {mr. moondial_quevedo, me has invitado a baila...
# 552 2025-11-25  {mr. moondial_quevedo, me has invitado a baila...
# 553 2025-11-26  {mr. moondial_quevedo, me has invitado a baila...
# 554 2025-11-27  {mr. moondial_quevedo, me has invitado a baila...
#
# [555 rows x 2 columns]

# %%
#entries = today - yesterday
#exits   = yesterday - today

entries = []
exits = []

for i in range(len(daily_songs)):
    if i == 0:
        entries.append(0)
        exits.append(0)
    else:
        prev_set = daily_songs.loc[i-1, 'song_id']
        curr_set = daily_songs.loc[i, 'song_id']
        
        new_entries = len(curr_set - prev_set)
        new_exits = len(prev_set - curr_set)
        
        entries.append(new_entries)
        exits.append(new_exits)

daily_songs['entries'] = entries
daily_songs['exits'] = exits

# %%
daily_songs
# Out:
#           date                                            song_id  entries  \
# 0   2024-05-18  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 1   2024-05-19  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 2   2024-05-20  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 3   2024-05-21  {antes_rvfv & edu garcía, classy 101_feid & yo...        4
# 4   2024-05-22  {antes_rvfv & edu garcía, classy 101_feid & yo...        1
# ..         ...                                                ...      ...
# 550 2025-11-23  {martini_dei v, me has invitado a bailar_dani ...        1
# 551 2025-11-24  {mr. moondial_quevedo, me has invitado a baila...       20
# 552 2025-11-25  {mr. moondial_quevedo, me has invitado a baila...        2
# 553 2025-11-26  {mr. moondial_quevedo, me has invitado a baila...        2
# 554 2025-11-27  {mr. moondial_quevedo, me has invitado a baila...        3
#
#      exits
# 0        0
# 1        0
# 2        0
# 3        4
# 4        1
# ..     ...
# 550      1
# 551     20
# 552      2
# 553      2
# 554      3
#
# [555 rows x 4 columns]

# %%
daily_songs['churn_rate'] = daily_songs['entries'] / 50

# playlist size = 50

# %%
daily_songs
# Out:
#           date                                            song_id  entries  \
# 0   2024-05-18  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 1   2024-05-19  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 2   2024-05-20  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 3   2024-05-21  {antes_rvfv & edu garcía, classy 101_feid & yo...        4
# 4   2024-05-22  {antes_rvfv & edu garcía, classy 101_feid & yo...        1
# ..         ...                                                ...      ...
# 550 2025-11-23  {martini_dei v, me has invitado a bailar_dani ...        1
# 551 2025-11-24  {mr. moondial_quevedo, me has invitado a baila...       20
# 552 2025-11-25  {mr. moondial_quevedo, me has invitado a baila...        2
# 553 2025-11-26  {mr. moondial_quevedo, me has invitado a baila...        2
# 554 2025-11-27  {mr. moondial_quevedo, me has invitado a baila...        3
#
#      exits  churn_rate
# 0        0        0.00
# 1        0        0.00
# 2        0        0.00
# 3        4        0.08
# 4        1        0.02
# ..     ...         ...
# 550      1        0.02
# 551     20        0.40
# 552      2        0.04
# 553      2        0.04
# 554      3        0.06
#
# [555 rows x 5 columns]

# %%
avg_churn = daily_songs['churn_rate'].mean()
avg_churn
# Out:
# np.float64(0.03434234234234235)

# %% [markdown]
# 0.03==3.4% of 50 ≈ 1.7 songs/day
# 1-2 songs change per day, very stable playlist

# %%
daily_songs['month'] = daily_songs['date'].dt.to_period('M')

monthly_churn = daily_songs.groupby('month')['churn_rate'].mean().reset_index()
daily_songs
# Out:
#           date                                            song_id  entries  \
# 0   2024-05-18  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 1   2024-05-19  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 2   2024-05-20  {antes_rvfv & edu garcía, classy 101_feid & yo...        0
# 3   2024-05-21  {antes_rvfv & edu garcía, classy 101_feid & yo...        4
# 4   2024-05-22  {antes_rvfv & edu garcía, classy 101_feid & yo...        1
# ..         ...                                                ...      ...
# 550 2025-11-23  {martini_dei v, me has invitado a bailar_dani ...        1
# 551 2025-11-24  {mr. moondial_quevedo, me has invitado a baila...       20
# 552 2025-11-25  {mr. moondial_quevedo, me has invitado a baila...        2
# 553 2025-11-26  {mr. moondial_quevedo, me has invitado a baila...        2
# 554 2025-11-27  {mr. moondial_quevedo, me has invitado a baila...        3
#
#      exits  churn_rate    month
# 0        0        0.00  2024-05
# 1        0        0.00  2024-05
# 2        0        0.00  2024-05
# 3        4        0.08  2024-05
# 4        1        0.02  2024-05
# ..     ...         ...      ...
# 550      1        0.02  2025-11
# 551     20        0.40  2025-11
# 552      2        0.04  2025-11
# 553      2        0.04  2025-11
# 554      3        0.06  2025-11
#
# [555 rows x 6 columns]

# %%
monthly_churn
# Out:
#       month  churn_rate
# 0   2024-05    0.028571
# 1   2024-06    0.024000
# 2   2024-07    0.020000
# 3   2024-08    0.021290
# 4   2024-09    0.026667
# 5   2024-10    0.038065
# 6   2024-11    0.030000
# 7   2024-12    0.043226
# 8   2025-01    0.040645
# 9   2025-02    0.019286
# 10  2025-03    0.035862
# 11  2025-04    0.053333
# 12  2025-05    0.034194
# 13  2025-06    0.038000
# 14  2025-07    0.031333
# 15  2025-08    0.038000
# 16  2025-09    0.030000
# 17  2025-10    0.032258
# 18  2025-11    0.067407

# %%
import plotly.express as px

fig = px.line(daily_songs, x='date', y='churn_rate', title='Daily Churn Rate')
fig.show()

# %%
monthly_churn['month'] = monthly_churn['month'].astype(str)

# %%
px.bar(monthly_churn, x='month', y='churn_rate', title='Monthly Churn Comparison')

# %%
daily_songs.to_csv("data/processed/daily_churn.csv", index=False)
